# %%
pip install panda
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7239 sha256=e6bf41d0deaa76cb8da488767b43dab16536b52b796bf0dd37ad108de3b4c085
#   Stored in directory: /root/.cache/pip/wheels/0e/8b/c3/ff9cbde1fffd8071cff8367a86f0350a1ce30a8d31b6a432e9
# Successfully built panda
# ...

# %%
pip install google-play-scraper

# %%
from google_play_scraper import Sort, reviews_all
import pandas as pd
import json

# %%
scrapreview1= reviews_all(
'com.spotify.music', #ID aplikasi
lang='id', # defaults to ‘en’
country='id', # defaults to ‘us’
sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
filter_score_with=None # defaults to None (means all score)
)

# %%
scrapreview2= reviews_all(
'com.spotify.music', #ID aplikasi
lang='id', # defaults to ‘en’
country='id', # defaults to ‘us’
sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
filter_score_with=None # defaults to None (means all score)
)

# %%
scrapreview = scrapreview1 +  scrapreview2

# %%
print(len(scrapreview1+scrapreview2))
# Out:
# 796

# %%
print(scrapreview)
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.to_csv('C:\iseng.csv', index=None, header=True)
# Out:
# [{'reviewId': '18c7a487-3039-40c1-bf17-0d49381f2d9b', 'userName': 'Testinganaja 2020', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW-wv9s4ErkcXaKIOc8DTuVnrcVZHJSVB15RoxGRvTjg00', 'content': 'bagus', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': None, 'at': datetime.datetime(2024, 3, 25, 18, 26, 23), 'replyContent': None, 'repliedAt': None, 'appVersion': None}, {'reviewId': '27a0bd1e-3d73-48fb-8a36-a170e38bb6d1', 'userName': 'Disti Dwi alika', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ71oD4Bt0yZWoAvfc2qu8Jkkgo9cxgtSBvJp0ts-it=mo', 'content': 'Aplikasi apa ini tidak bisa di download 👎', 'score': 1, 'thumbsUpCount': 0, 'reviewCreatedVersion': None, 'at': datetime.datetime(2024, 3, 25, 17, 31, 18), 'replyContent': None, 'repliedAt': None, 'appVersion': None}, {'reviewId': 'e1747e42-5711-456d-b3d9-ef1f135bf95d', 'userName': 'Andi Saputra', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKwc3pMl-J3q5_QoQ-PRf0H_4IuW3z_l1ELXdG17hz7=mo
# ...
